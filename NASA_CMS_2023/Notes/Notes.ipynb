# %% [markdown]
# # JRC Layers

# %%
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_180E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_060E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_000W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_030W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_120W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_130W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_140W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_150W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_160W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_170W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N90&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N80&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N70&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N60&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N50&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N40&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N30&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N20&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N10&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_00N_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=N0&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_10S_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S10&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_20S_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S20&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_30S_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S30&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_40S_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S40&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_50S_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S50&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_60S_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S60&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_70S_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S70&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_80S_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S80&lon=W180"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_FC/JRC_FC_90S_180W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/gfc2020/download.py?version=v2&type=tile&lat=S90&lon=W180"

# %%
################ Python 3.10.13 | packaged by conda-forge ################
################ Python 3.10.13 | packaged by conda-forge ################
################ Python 3.10.13 | packaged by conda-forge ################

import os 
import rasterio
os.chdir("/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/")

# ####### CREATE EMPTY JRC LAYERS (only 0 values) FOR MISSING TILES ###########
# Blank = rasterio.open("./JRC_DEG/00N_000E_JRC_Degradation_Map.tif").read(1)
# Blank = Blank*0
# kwargs = rasterio.open("./JRC_DEG/00N_000E_JRC_Degradation_Map.tif").meta
# kwargs.update(dtype=rasterio.int16,count=1,compress='lzw',nodata=-9999) 

# TILES = ["00N_000E","00N_010E","00N_020E","00N_030E","00N_040E","00N_040W","00N_050E","00N_050W","00N_060W","00N_070E","00N_070W","00N_080W","00N_090E","00N_090W","00N_100E","00N_100W","00N_110E","00N_120E","00N_130E","00N_140E","00N_150E","00N_160E","00N_170E","10N_000E","10N_010E","10N_010W","10N_020E","10N_020W","10N_030E","10N_040E","10N_050E","10N_050W","10N_060W","10N_070E","10N_070W","10N_080E","10N_080W","10N_090E","10N_090W","10N_100E","10N_100W","10N_110E","10N_120E","10N_130E","10N_150E","10N_160E","10N_170E","10S_010E","10S_020E","10S_030E","10S_040E","10S_040W","10S_050E","10S_050W","10S_060W","10S_070W","10S_080W","10S_110E","10S_120E","10S_130E","10S_140E","10S_150E","10S_160E","10S_170E","10S_180W","20N_000E","20N_010E","20N_010W","20N_020E","20N_020W","20N_030E","20N_030W","20N_040E","20N_050E","20N_060W","20N_070E","20N_070W","20N_080E","20N_080W","20N_090E","20N_090W","20N_100E","20N_100W","20N_110E","20N_110W","20N_120E","20N_120W","20N_160W","20S_010E","20S_020E","20S_030E","20S_040E","20S_050E","20S_050W","20S_060W","20S_070W","20S_080W","20S_110E","20S_120E","20S_130E","20S_140E","20S_150E","20S_160E","20S_180W","30N_000E","30N_010E","30N_010W","30N_020E","30N_020W","30N_030E","30N_040E","30N_050E","30N_060E","30N_070E","30N_080E","30N_080W","30N_090E","30N_090W","30N_100E","30N_100W","30N_110E","30N_110W","30N_120E","30N_120W","30N_130E","30N_160W","30N_170W","30S_010E","30S_020E","30S_030E","30S_060W","30S_070W","30S_080W","30S_110E","30S_120E","30S_130E","30S_140E","30S_150E","30S_170E","40N_000E","40N_010E","40N_010W","40N_020E","40N_020W","40N_030E","40N_040E","40N_050E","40N_060E","40N_070E","40N_070W","40N_080E","40N_080W","40N_090E","40N_090W","40N_100E","40N_100W","40N_110E","40N_110W","40N_120E","40N_120W","40N_130E","40N_130W","40N_140E","40S_070W","40S_080W","40S_140E","40S_160E","40S_170E","50N_000E","50N_010E","50N_010W","50N_020E","50N_030E","50N_040E","50N_050E","50N_060E","50N_060W","50N_070E","50N_070W","50N_080E","50N_080W","50N_090E","50N_090W","50N_100E","50N_100W","50N_110E","50N_110W","50N_120E","50N_120W","50N_130E","50N_130W","50N_140E","50N_150E","50S_060W","50S_070W","50S_080W","60N_000E","60N_010E","60N_010W","60N_020E","60N_020W","60N_030E","60N_040E","60N_050E","60N_060E","60N_060W","60N_070E","60N_070W","60N_080E","60N_080W","60N_090E","60N_090W","60N_100E","60N_100W","60N_110E","60N_110W","60N_120E","60N_120W","60N_130E","60N_130W","60N_140E","60N_140W","60N_150E","60N_150W","60N_160E","60N_160W","60N_170E","60N_170W","60N_180W","70N_000E","70N_010E","70N_020E","70N_030E","70N_040E","70N_050E","70N_060E","70N_070E","70N_070W","70N_080E","70N_080W","70N_090E","70N_090W","70N_100E","70N_100W","70N_110E","70N_110W","70N_120E","70N_120W","70N_130E","70N_130W","70N_140E","70N_140W","70N_150E","70N_150W","70N_160E","70N_160W","70N_170E","70N_170W","70N_180W","80N_010E","80N_020E","80N_030E","80N_070E","80N_080E","80N_090E","80N_100E","80N_110E","80N_120E","80N_130E","80N_130W","80N_140E","80N_140W","80N_150E","80N_150W","80N_160E","80N_160W","80N_170E","80N_170W"]
# for TILE in TILES: 
#     if not os.path.exists("./JRC_DEG/"+TILE+"_JRC_Degradation_Map.tif"):
#         with rasterio.open("./JRC_DEG/"+TILE+"_JRC_Degradation_Map.tif", 'w', **kwargs) as dst: dst.write_band(1, Blank.astype(rasterio.int16))    

# ####### CREATE EMPTY JRC LAYERS (only 0 values) FOR MISSING TILES ###########
# Blank = rasterio.open("./JRC_DEF/00N_000E_JRC_Deforestation_Map.tif").read(1)
# Blank = Blank*0
# kwargs = rasterio.open("./JRC_DEF/00N_000E_JRC_Deforestation_Map.tif").meta
# kwargs.update(dtype=rasterio.int16,count=1,compress='lzw', nodata=-9999) 

# TILES = ["00N_000E","00N_010E","00N_020E","00N_030E","00N_040E","00N_040W","00N_050E","00N_050W","00N_060W","00N_070E","00N_070W","00N_080W","00N_090E","00N_090W","00N_100E","00N_100W","00N_110E","00N_120E","00N_130E","00N_140E","00N_150E","00N_160E","00N_170E","10N_000E","10N_010E","10N_010W","10N_020E","10N_020W","10N_030E","10N_040E","10N_050E","10N_050W","10N_060W","10N_070E","10N_070W","10N_080E","10N_080W","10N_090E","10N_090W","10N_100E","10N_100W","10N_110E","10N_120E","10N_130E","10N_150E","10N_160E","10N_170E","10S_010E","10S_020E","10S_030E","10S_040E","10S_040W","10S_050E","10S_050W","10S_060W","10S_070W","10S_080W","10S_110E","10S_120E","10S_130E","10S_140E","10S_150E","10S_160E","10S_170E","10S_180W","20N_000E","20N_010E","20N_010W","20N_020E","20N_020W","20N_030E","20N_030W","20N_040E","20N_050E","20N_060W","20N_070E","20N_070W","20N_080E","20N_080W","20N_090E","20N_090W","20
# for TILE in TILES: 
#     if not os.path.exists("./JRC_FC/"+TILE+"_JRC_ForestCover_Map.tif"):
#         print("creating..." + "./JRC_FC/"+TILE+"_JRC_ForestCover_Map.tif")
#         with rasterio.open("./JRC_FC/"+TILE+"_JRC_ForestCover_Map.tif", 'w', **kwargs) as dst: dst.write_band(1, Blank.astype(rasterio.int16))    


# ####### CREATE EMPTY JRC LAYERS (only 0 values) FOR MISSING TILES ###########
# Blank = rasterio.open("./JRC_TFM/00N_000E_JRC_Transition_Map.tif").read(1)
# Blank = Blank*0
# kwargs = rasterio.open("./JRC_TFM/00N_000E_JRC_Transition_Map.tif").meta
# kwargs.update(dtype=rasterio.int16,count=1,compress='lzw', nodata=-9999) 

# TILES = ["00N_000E","00N_010E","00N_020E","00N_030E","00N_040E","00N_040W","00N_050E","00N_050W","00N_060W","00N_070E","00N_070W","00N_080W","00N_090E","00N_090W","00N_100E","00N_100W","00N_110E","00N_120E","00N_130E","00N_140E","00N_150E","00N_160E","00N_170E","10N_000E","10N_010E","10N_010W","10N_020E","10N_020W","10N_030E","10N_040E","10N_050E","10N_050W","10N_060W","10N_070E","10N_070W","10N_080E","10N_080W","10N_090E","10N_090W","10N_100E","10N_100W","10N_110E","10N_120E","10N_130E","10N_150E","10N_160E","10N_170E","10S_010E","10S_020E","10S_030E","10S_040E","10S_040W","10S_050E","10S_050W","10S_060W","10S_070W","10S_080W","10S_110E","10S_120E","10S_130E","10S_140E","10S_150E","10S_160E","10S_170E","10S_180W","20N_000E","20N_010E","20N_010W","20N_020E","20N_020W","20N_030E","20N_030W","20N_040E","20N_050E","20N_060W","20N_070E","20N_070W","20N_080E","20N_080W","20N_090E","20N_090W","20N_100E","20N_100W","20N_110E","20N_110W","20N_120E","20N_120W","20N_160W","20S_010E","20S_020E","20S_030E","20S_040E","20S_050E","20S_050W","20S_060W","20S_070W","20S_080W","20S_110E","20S_120E","20S_130E","20S_140E","20S_150E","20S_160E","20S_180W","30N_000E","30N_010E","30N_010W","30N_020E","30N_020W","30N_030E","30N_040E","30N_050E","30N_060E","30N_070E","30N_080E","30N_080W","30N_090E","30N_090W","30N_100E","30N_100W","30N_110E","30N_110W","30N_120E","30N_120W","30N_130E","30N_160W","30N_170W","30S_010E","30S_020E","30S_030E","30S_060W","30S_070W","30S_080W","30S_110E","30S_120E","30S_130E","30S_140E","30S_150E","30S_170E","40N_000E","40N_010E","40N_010W","40N_020E","40N_020W","40N_030E","40N_040E","40N_050E","40N_060E","40N_070E","40N_070W","40N_080E","40N_080W","40N_090E","40N_090W","40N_100E","40N_100W","40N_110E","40N_110W","40N_120E","40N_120W","40N_130E","40N_130W","40N_140E","40S_070W","40S_080W","40S_140E","40S_160E","40S_170E","50N_000E","50N_010E","50N_010W
# creating..../JRC_TFM/10N_130E_JRC_Transition_Map.tif
# creating..../JRC_TFM/10N_150E_JRC_Transition_Map.tif
# creating..../JRC_TFM/10N_160E_JRC_Transition_Map.tif
# creating..../JRC_TFM/10N_170E_JRC_Transition_Map.tif
# creating..../JRC_TFM/10S_110E_JRC_Transition_Map.tif
# creating..../JRC_TFM/10S_180W_JRC_Transition_Map.tif
# creating..../JRC_TFM/20N_000E_JRC_Transition_Map.tif
# creating..../JRC_TFM/20N_010E_JRC_Transition_Map.tif
# creating..../JRC_TFM/20N_010W_JRC_Transition_Map.tif
# creating..../JRC_TFM/20N_020E_JRC_Transition_Map.tif
# creating..../JRC_TFM/20N_030E_JRC_Transition_Map.tif
# creating..../JRC_TFM/20N_030W_JRC_Transition_Map.tif
# ...

# %%
####### CREATE EMPTY SPDT LAYERS (only 0 values) FOR MISSING TILES ###########
Blank = rasterio.open("./SPDT_v21/TIFs/C_SDPT_v21_10S_180W.tif").read(1)
Blank = Blank*0
kwargs = rasterio.open("./SPDT_v21/TIFs/C_SDPT_v21_10S_180W.tif").meta
kwargs.update(dtype=rasterio.int16,count=1,compress='lzw', nodata=-9999) 

TILES = ["00N_000E","00N_010E","00N_020E","00N_030E","00N_040E","00N_040W","00N_050E","00N_050W","00N_060W","00N_070E","00N_070W","00N_080W","00N_090E","00N_090W","00N_100E","00N_100W","00N_110E","00N_120E","00N_130E","00N_140E","00N_150E","00N_160E","00N_170E","10N_000E","10N_010E","10N_010W","10N_020E","10N_020W","10N_030E","10N_040E","10N_050E","10N_050W","10N_060W","10N_070E","10N_070W","10N_080E","10N_080W","10N_090E","10N_090W","10N_100E","10N_100W","10N_110E","10N_120E","10N_130E","10N_150E","10N_160E","10N_170E","10S_010E","10S_020E","10S_030E","10S_040E","10S_040W","10S_050E","10S_050W","10S_060W","10S_070W","10S_080W","10S_110E","10S_120E","10S_130E","10S_140E","10S_150E","10S_160E","10S_170E","10S_180W","20N_000E","20N_010E","20N_010W","20N_020E","20N_020W","20N_030E","20N_030W","20N_040E","20N_050E","20N_060W","20N_070E","20N_070W","20N_080E","20N_080W","20N_090E","20N_090W","20N_100E","20N_100W","20N_110E","20N_110W","20N_120E","20N_120W","20N_160W","20S_010E","20S_020E","20S_030E","20S_040E","20S_050E","20S_050W","20S_060W","20S_070W","20S_080W","20S_110E","20S_120E","20S_130E","20S_140E","20S_150E","20S_160E","20S_180W","30N_000E","30N_010E","30N_010W","30N_020E","30N_020W","30N_030E","30N_040E","30N_050E","30N_060E","30N_070E","30N_080E","30N_080W","30N_090E","30N_090W","30N_100E","30N_100W","30N_110E","30N_110W","30N_120E","30N_120W","30N_130E","30N_160W","30N_170W","30S_010E","30S_020E","30S_030E","30S_060W","30S_070W","30S_080W","30S_110E","30S_120E","30S_130E","30S_140E","30S_150E","30S_170E","40N_000E","40N_010E","40N_010W","40N_020E","40N_020W","40N_030E","40N_040E","40N_050E","40N_060E","40N_070E","40N_070W","40N_080E","40N_080W","40N_090E","40N_090W","40N_100E","40N_100W","40N_110E","40N_110W","40N_120E","40N_120W","40N_130E","40N_130W","40N_140E","40S_070W","40S_080W","40S_140E","40S_160E","40S_170E","50N_000E","50N_010E","50N_010W","50N_020E","50N_030E","50N_040E","50N_050E","50N_060E","50N_060W","50N_070E","50N_070W","50N_080E","50N_080W","50N_090E","50N_090W","50N_100E","50N_100W","50N_110E","50N_110W","50N_120E","50N_120W","50N_130E","50N_130W","50N_140E","50N_150E","50S_060W","50S_070W","50S_080W","60N_000E","60N_010E","60N_010W","60N_020E","60N_020W","60N_030E","60N_040E","60N_050E","60N_060E","60N_060W","60N_070E","60N_070W","60N_080E","60N_080W","60N_090E","60N_090W","60N_100E","60N_100W","60N_110E","60N_110W","60N_120E","60N_120W","60N_130E","60N_130W","60N_140E","60N_140W","60N_150E","60N_150W","60N_160E","60N_160W","60N_170E","60N_170W","60N_180W","70N_000E","70N_010E","70N_020E","70N_030E","70N_040E","70N_050E","70N_060E","70N_070E","70N_070W","70N_080E","70N_080W","70N_090E","70N_090W","70N_100E","70N_100W","70N_110E","70N_110W","70N_120E","70N_120W","70N_130E","70N_130W","70N_140E","70N_140W","70N_150E","70N_150W","70N_160E","70N_160W","70N_170E","70N_170W","70N_180W","80N_010E","80N_020E","80N_030E","80N_070E","80N_080E","80N_090E","80N_100E","80N_110E","80N_120E","80N_130E","80N_130W","80N_140E","80N_140W","80N_150E","80N_150W","80N_160E","80N_160W","80N_170E","80N_170W"]
for TILE in TILES: 
    if not os.path.exists("./SPDT_v21/TIFs/C_SDPT_v21_"+TILE+".tif"):
        print("creating..." + "./SPDT_v21/TIFs/C_SDPT_v21_"+TILE+".tif")
        with rasterio.open("./SPDT_v21/TIFs/C_SDPT_v21_"+TILE+".tif", 'w', **kwargs) as dst: dst.write_band(1, Blank.astype(rasterio.int16))
# Out:
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_060W.tif
# /tmp/ipykernel_5125/3660017383.py:11: RuntimeWarning: invalid value encountered in cast
#   with rasterio.open("./SPDT_v21/TIFs/C_SDPT_v21_"+TILE+".tif", 'w', **kwargs) as dst: dst.write_band(1, Blank.astype(rasterio.int16))
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_070E.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_070W.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_080E.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_080W.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_090E.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_090W.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_100E.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_100W.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_110E.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_120E.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_150E.tif
# creating..../SPDT_v21/TIFs/C_SDPT_v21_10N_160E.tif
","60N_100W","60N_110E","60N_110W","60N_120E","60N_120W","60N_130E","60N_130W","60N_140E","60N_140W","60N_150E","60N_150W","60N_160E","60N_160W","60N_170E","60N_170W","60N_180W","70N_000E","70N_010E","70N_020E","70N_030E","70N_040E","70N_050E","70N_060E","70N_070E","70N_070W","70N_080E","70N_080W","70N_090E","70N_090W","70N_100E","70N_100W","70N_110E","70N_110W","70N_120E","70N_120W","70N_130E","70N_130W","70N_140E","70N_140W","70N_150E","70N_150W","70N_160E","70N_160W","70N_170E","70N_170W","70N_180W","80N_010E","80N_020E","80N_030E","80N_070E","80N_080E","80N_090E","80N_100E","80N_110E","80N_120E","80N_130E","80N_130W","80N_140E","80N_140W","80N_150E","80N_150W","80N_160E","80N_160W","80N_170E","80N_170W"]
for TILE in TILES: 
    if not os.path.exists("./EU_PrimaryForests/TIFs/PF_Europe__"+TILE+".tif"):
        print("creating..." + "./EU_PrimaryForests/TIFs/PF_Europe__"+TILE+".tif")
        with rasterio.open("./EU_PrimaryForests/TIFs/PF_Europe__"+TILE+".tif", 'w', **kwargs) as dst: dst.write_band(1, Blank.astype(rasterio.int16))
# Out:
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_000E.tif
# /tmp/ipykernel_5125/3763963201.py:11: RuntimeWarning: invalid value encountered in cast
#   with rasterio.open("./EU_PrimaryForests/TIFs/PF_Europe__"+TILE+".tif", 'w', **kwargs) as dst: dst.write_band(1, Blank.astype(rasterio.int16))
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_010E.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_020E.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_030E.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_040E.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_040W.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_050E.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_050W.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_060W.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_070E.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_070W.tif
# creating..../EU_PrimaryForests/TIFs/PF_Europe__00N_080W.tif
# ...

# %%
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N30&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N30&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N30&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N30&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S20&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S20&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S20&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S30&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_000E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_000E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S20&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S20&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N30&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N30&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N30&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N30&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N30&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N20&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N10&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_00N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=N0&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_10S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S10&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S20&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S20&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_20S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S20&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S30&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM/JRC_TMST_30S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=TransitionMap_Subtypes&lat=S30&lon=E150"

# %%
library(terra)

# Define input and output folders
input_folder <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM'
output_folder <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_TFM'

# List all files in the input folder starting with "JRC_TMST"
files <- list.files(input_folder, pattern = "^JRC_TMST.*\\.tif$", full.names = TRUE)

# Loop through each file and process it
for (input_file in files) {
    # Generate output file name
    outname_extent <- strsplit(basename(input_file), "TMST_")[[1]][2]
    outname_extent <- strsplit(outname_extent, ".tif")[[1]][1]
    output_file <- file.path(output_folder, paste0(outname_extent, "_JRC_Transition_Map.tif")) 
    if (!file.exists(output_file)) {
        tile_string <- outname_extent
        parts <- strsplit(tile_string, "_")[[1]]
        
        ymax_str <- substr(parts[1], 1, 2) # Extract the numeric part of ymax
        ymax_dir <- substr(parts[1], 3, 3) # Extract the direction (N/S)
        xmin_str <- substr(parts[2], 1, 3) # Extract the numeric part of xmin
        xmin_dir <- substr(parts[2], 4, 4) # Extract the direction (E/W)
    
        ymax <- as.numeric(ymax_str)
        if (ymax_dir == "S") {ymax <- -ymax}
        
        xmin <- as.numeric(xmin_str)
        if (xmin_dir == "W") {xmin <- -xmin}
        
        xmax <- xmin + 10
        ymin <- ymax - 10
        target_extent <- ext(xmin, xmax, ymin, ymax)
        
        # Define resolution and nodata value
        resolution <- c(0.00025, 0.00025)
        nodata_value <- 0.0 
        r <- rast(input_file)
        
        # Create an empty raster with the target extent and resolution
        target_raster <- rast(extent = target_extent, resolution = resolution, crs = crs(r))
        
        # Apply warp (resampling and reprojecting)
        r_warped <- resample(r, target_raster, method = "near")
        
        # Write the warped raster to the output file
        writeRaster(r_warped, output_file, overwrite = TRUE, gdal = c("COMPRESS=DEFLATE", "PREDICTOR=2", "ZLEVEL=9"))
    }
}
# Out:
# terra 1.7.29

# %%
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N30&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N30&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N30&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N30&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S20&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S20&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S20&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S30&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_000E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_000E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S20&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S20&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N30&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N30&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N30&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N30&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N30&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N20&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N10&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_00N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=N0&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_10S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S10&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S20&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S20&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_20S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S20&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S30&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF/JRC_DEF_30S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DeforestationYear&lat=S30&lon=E150"

# %%
library(terra)

# Define input and output folders
input_folder <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF'
output_folder <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEF'

# List all files in the input folder starting with "JRC_TMST"
files <- list.files(input_folder, pattern = "JRC_DEF*", full.names = TRUE)

# Loop through each file and process it
for (input_file in files) {
    # Generate output file name
    outname_extent <- strsplit(basename(input_file), "DEF_")[[1]][2]
    outname_extent <- strsplit(outname_extent, ".tif")[[1]][1]
    output_file <- file.path(output_folder, paste0(outname_extent, "_JRC_Deforestation_Map.tif")) 
    if (!file.exists(output_file)) {
        tile_string <- outname_extent
        parts <- strsplit(tile_string, "_")[[1]]
        
        ymax_str <- substr(parts[1], 1, 2) # Extract the numeric part of ymax
        ymax_dir <- substr(parts[1], 3, 3) # Extract the direction (N/S)
        xmin_str <- substr(parts[2], 1, 3) # Extract the numeric part of xmin
        xmin_dir <- substr(parts[2], 4, 4) # Extract the direction (E/W)
    
        ymax <- as.numeric(ymax_str)
        if (ymax_dir == "S") {ymax <- -ymax}
        
        xmin <- as.numeric(xmin_str)
        if (xmin_dir == "W") {xmin <- -xmin}
        
        xmax <- xmin + 10
        ymin <- ymax - 10
        target_extent <- ext(xmin, xmax, ymin, ymax)
        
        # Define resolution and nodata value
        resolution <- c(0.00025, 0.00025)
        nodata_value <- 0.0 
        r <- rast(input_file)
        
        # Create an empty raster with the target extent and resolution
        target_raster <- rast(extent = target_extent, resolution = resolution, crs = crs(r))
        
        # Apply warp (resampling and reprojecting)
        r_warped <- resample(r, target_raster, method = "near")
        
        # Write the warped raster to the output file
        writeRaster(r_warped, output_file, overwrite = TRUE, gdal = c("COMPRESS=DEFLATE", "PREDICTOR=2", "ZLEVEL=9"))
    }
}

# %%
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N30&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N30&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N30&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N30&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_110W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=W110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_100W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=W100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_090W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=W90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_080W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=W80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_040W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=W40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20S_070W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S20&lon=W70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S20&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20S_050W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S20&lon=W50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30S_060W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S30&lon=W60"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_020W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=W20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_010W.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=W10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_000E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_000E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E0"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_010E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E10"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_020E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E20"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_030E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E30"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20S_040E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S20&lon=E40"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20S_050E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S20&lon=E50"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N30&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N30&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N30&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N30&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N30&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N20&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_070E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E70"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_080E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E80"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N10&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_090E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E90"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_100E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E100"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_110E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E110"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_00N_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=N0&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_120E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E120"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_130E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E130"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_10S_170E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S10&lon=E170"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S20&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S20&lon=E150"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_20S_160E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S20&lon=E160"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30S_140E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S30&lon=E140"
curl -o /projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG/JRC_DEG_30S_150E.tif -L "https://ies-ows.jrc.ec.europa.eu/iforce/tmf_v1/download.py?type=tile&dataset=DegradationYear&lat=S30&lon=E150"

# %%
library(terra)

# Define input and output folders
input_folder <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG'
output_folder <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/JRC_DEG'

# List all files in the input folder starting with "JRC_TMST"
files <- list.files(input_folder, pattern = "JRC_DEG*", full.names = TRUE)

# Loop through each file and process it
for (input_file in files) {
    # Generate output file name
    outname_extent <- strsplit(basename(input_file), "DEG_")[[1]][2]
    outname_extent <- strsplit(outname_extent, ".tif")[[1]][1]
    output_file <- file.path(output_folder, paste0(outname_extent, "_JRC_Degradation_Map.tif")) 
    if (!file.exists(output_file)) {
        tile_string <- outname_extent
        parts <- strsplit(tile_string, "_")[[1]]
        
        ymax_str <- substr(parts[1], 1, 2) # Extract the numeric part of ymax
        ymax_dir <- substr(parts[1], 3, 3) # Extract the direction (N/S)
        xmin_str <- substr(parts[2], 1, 3) # Extract the numeric part of xmin
        xmin_dir <- substr(parts[2], 4, 4) # Extract the direction (E/W)
    
        ymax <- as.numeric(ymax_str)
        if (ymax_dir == "S") {ymax <- -ymax}
        
        xmin <- as.numeric(xmin_str)
        if (xmin_dir == "W") {xmin <- -xmin}
        
        xmax <- xmin + 10
        ymin <- ymax - 10
        target_extent <- ext(xmin, xmax, ymin, ymax)
        
        # Define resolution and nodata value
        resolution <- c(0.00025, 0.00025)
        nodata_value <- 0.0 
        r <- rast(input_file)
        
        # Create an empty raster with the target extent and resolution
        target_raster <- rast(extent = target_extent, resolution = resolution, crs = crs(r))
        
        # Apply warp (resampling and reprojecting)
        r_warped <- resample(r, target_raster, method = "near")
        
        # Write the warped raster to the output file
        writeRaster(r_warped, output_file, overwrite = TRUE, gdal = c("COMPRESS=DEFLATE", "PREDICTOR=2", "ZLEVEL=9"))
    }
}

# %%
import os
from osgeo import gdal
import math
import subprocess

def get_gpkg_extent(file_path):
    # Open the GeoPackage
    dataset = gdal.OpenEx(file_path, gdal.OF_VECTOR)
    if not dataset:
        raise FileNotFoundError(f"Unable to open the file: {file_path}")
    
    # Get the layer
    layer = dataset.GetLayer()
    if not layer:
        raise ValueError("No layers found in the GeoPackage.")
    
    # Get the extent
    extent = layer.GetExtent()  # Returns (minX, maxX, minY, maxY)
    dataset = None  # Close the dataset
    return extent

def calculate_10x10_grid(extent):
    min_lon, max_lon, min_lat, max_lat = extent
    
    # Calculate the 10x10 grid boundaries
    grid_min_lon = math.floor(min_lon / 10) * 10
    grid_max_lon = math.ceil(max_lon / 10) * 10
    grid_min_lat = math.floor(min_lat / 10) * 10
    grid_max_lat = math.ceil(max_lat / 10) * 10

    return grid_min_lon, grid_max_lon, grid_min_lat, grid_max_lat

def format_extent_string(grid_extent):
    min_lon, max_lon, min_lat, max_lat = grid_extent

    # Convert to formatted strings with N/S and E/W indicators
    def format_coord(value, positive_char, negative_char, digits=2):
        abs_value = abs(value)
        direction = positive_char if value >= 0 else negative_char
        return f"{int(abs_value):0{digits}}{direction}"
    
    west = format_coord(min_lon, "E", "W", digits=3)
    south = format_coord(max_lat, "N", "S")
    
    return f"{south}_{west}"

def rasterize_gpkg(file_path, grid_extent, output_folder):
    # Format the extent string for the output filename
    extent_string = format_extent_string(grid_extent)

    # Define the output file name
    base_name = os.path.basename(file_path).replace(".gpkg", "")
    base_name_out = base_name.split("id_")[0]
    output_file_name = f"{base_name_out}_{extent_string}.tif"
    output_path = os.path.join(output_folder, output_file_name)
    
    # Construct the target extent
    te = f"{grid_extent[0]},{grid_extent[1]},{grid_extent[2]},{grid_extent[3]}"
    
    # gdal_rasterize command
    command = f"vector_file <- '{file_path}';output_raster <- '{output_path}'; vector_data <- vect(vector_file, layer = '{base_name}'); extent <- ext({te}); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));"
    if not os.path.exists(output_path): print(command)    

def process_gpkg_files(folder_path, output_folder):
    # Ensure the output folder exists
    os.makedirs(output_folder, exist_ok=True)

    # Iterate over all .gpkg files in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".gpkg"):
            file_path = os.path.join(folder_path, file_name)
            try:
                # Get the extent of the GeoPackage
                extent = get_gpkg_extent(file_path)
                grid_extent = calculate_10x10_grid(extent)
                rasterize_gpkg(file_path, grid_extent, output_folder)
            except Exception as e:
                print(f"Error processing file {file_name}: {e}")

# Specify the folder containing .gpkg files and the output folder for rasters
input_folder = "/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/"
output_folder = "/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/"

process_gpkg_files(input_folder, output_folder)
# Out:
# vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_447.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__40N_020W.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_447'); extent <- ext(-20,-10,30,40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
# ...

# %%
library(terra)
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_447.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__40N_020W.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_447'); extent <- ext(-20,-10,30,40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_448.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__30N_020W.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_448'); extent <- ext(-20,-10,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_473.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__50N_010W.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_473'); extent <- ext(-10,0,40,50); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_474.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__40N_010W.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_474'); extent <- ext(-10,0,30,40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_498.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__70N_000E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_498'); extent <- ext(0,10,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_499.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__60N_000E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_499'); extent <- ext(0,10,50,60); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_500.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__50N_000E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_500'); extent <- ext(0,10,40,50); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_526.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__60N_010E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_526'); extent <- ext(10,20,50,60); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_527.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__50N_010E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_527'); extent <- ext(10,20,40,50); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_528.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__40N_010E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_528'); extent <- ext(10,20,30,40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_551.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__80N_020E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_551'); extent <- ext(20,30,70,80); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_552.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__70N_020E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_552'); extent <- ext(20,30,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_553.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__60N_020E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_553'); extent <- ext(20,30,50,60); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_554.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__50N_020E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_554'); extent <- ext(20,30,40,50); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_555.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__40N_020E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_555'); extent <- ext(20,30,30,40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_579.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__70N_030E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_579'); extent <- ext(30,40,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_580.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__60N_030E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_580'); extent <- ext(30,40,50,60); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_581.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__50N_030E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_581'); extent <- ext(30,40,40,50); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_606.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__70N_040E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_606'); extent <- ext(40,50,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_607.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__60N_040E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_607'); extent <- ext(40,50,50,60); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_608.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__50N_040E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_608'); extent <- ext(40,50,40,50); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_633.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__70N_050E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_633'); extent <- ext(50,60,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_634.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__60N_050E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_634'); extent <- ext(50,60,50,60); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/GPKGs/PF_Europe_id_660.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/EU_PrimaryForests/TIFs/PF_Europe__70N_060E.tif'; vector_data <- vect(vector_file, layer = 'PF_Europe_id_660'); extent <- ext(60,70,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
# Out:
# terra 1.7.29

# %%
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_115.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30N_120W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_115'); extent <- ext(-120,-110,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_187.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30N_080W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_187'); extent <- ext(-80,-70,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_208.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_00N_070W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_208'); extent <- ext(-70,-60,-10,0); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_212.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_40S_070W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_212'); extent <- ext(-70,-60,-50,-40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_276.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_40N_030W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_276'); extent <- ext(-30,-20,30,40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_295.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30N_020W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_295'); extent <- ext(-20,-10,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_309.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_70N_010W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_309'); extent <- ext(-10,0,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_313.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30N_010W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_313'); extent <- ext(-10,0,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_331.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30N_000E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_331'); extent <- ext(0,10,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_332.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20N_000E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_332'); extent <- ext(0,10,10,20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_344.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_80N_010E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_344'); extent <- ext(10,20,70,80); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_349.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30N_010E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_349'); extent <- ext(10,20,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_350.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20N_010E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_350'); extent <- ext(10,20,10,20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_353.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_10S_010E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_353'); extent <- ext(10,20,-20,-10); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_362.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_80N_020E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_362'); extent <- ext(20,30,70,80); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_367.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30N_020E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_367'); extent <- ext(20,30,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_368.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20N_020E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_368'); extent <- ext(20,30,10,20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_385.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30N_030E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_385'); extent <- ext(30,40,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_404.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20N_040E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_404'); extent <- ext(40,50,10,20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_406.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_00N_040E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_406'); extent <- ext(40,50,-10,0); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_407.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_10S_040E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_407'); extent <- ext(40,50,-20,-10); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_408.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20S_040E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_408'); extent <- ext(40,50,-30,-20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_422.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20N_050E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_422'); extent <- ext(50,60,10,20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_425.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_10S_050E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_425'); extent <- ext(50,60,-20,-10); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_489.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_70N_090E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_489'); extent <- ext(90,100,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_491.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_50N_090E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_491'); extent <- ext(90,100,40,50); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_492.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_40N_090E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_492'); extent <- ext(90,100,30,40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_507.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_70N_100E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_507'); extent <- ext(100,110,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_525.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_70N_110E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_525'); extent <- ext(110,120,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_529.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30N_110E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_529'); extent <- ext(110,120,20,30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_534.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20S_110E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_534'); extent <- ext(110,120,-30,-20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_551.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_10S_120E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_551'); extent <- ext(120,130,-20,-10); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_552.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20S_120E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_552'); extent <- ext(120,130,-30,-20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_561.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_70N_130E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_561'); extent <- ext(130,140,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_562.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_60N_130E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_562'); extent <- ext(130,140,50,60); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_567.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_10N_130E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_567'); extent <- ext(130,140,0,10); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_57.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_70N_150W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_57'); extent <- ext(-150,-140,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_570.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20S_130E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_570'); extent <- ext(130,140,-30,-20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_582.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_40N_140E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_582'); extent <- ext(140,150,30,40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_598.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_60N_150E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_598'); extent <- ext(150,160,50,60); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_599.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_50N_150E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_599'); extent <- ext(150,160,40,50); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_615.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_70N_160E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_615'); extent <- ext(160,170,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_616.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_60N_160E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_616'); extent <- ext(160,170,50,60); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_623.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_10S_160E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_623'); extent <- ext(160,170,-20,-10); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_624.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_20S_160E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_624'); extent <- ext(160,170,-30,-20); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_626.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_40S_160E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_626'); extent <- ext(160,170,-50,-40); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_641.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_10S_170E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_641'); extent <- ext(170,180,-20,-10); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_643.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_30S_170E.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_643'); extent <- ext(170,180,-40,-30); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
vector_file <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/GPKGs/C_SDPT_v21id_93.gpkg';output_raster <- '/projects/my-public-bucket/Data/Hunka_et_al_PAPER_NSD/SPDT_v21/TIFs/C_SDPT_v21_70N_130W.tif'; vector_data <- vect(vector_file, layer = 'C_SDPT_v21id_93'); extent <- ext(-130,-120,60,70); resolution <- c(0.00025, 0.00025); r <- rast(extent, resolution = resolution, crs = crs(vector_data)); r <- rasterize(vector_data, r, field=1, verbose = TRUE); writeRaster(r, output_raster, overwrite = TRUE, gdal = c('COMPRESS=DEFLATE', 'PREDICTOR=2', 'ZLEVEL=9'));
